# %% [markdown]
# # Imports

# %%
import os 
import gym_super_mario_bros
from nes_py.wrappers import JoypadSpace
from gym_super_mario_bros.actions import SIMPLE_MOVEMENT
from gym.wrappers import GrayScaleObservation
from stable_baselines3.common.vec_env import VecFrameStack, DummyVecEnv
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
from matplotlib import pyplot as plt

# %%
env = gym_super_mario_bros.make('SuperMarioBros-v0')
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %% [markdown]
# ### Init test

# %%
done = True
for step in range(100000): 
    if done: 
        env.reset()
    state, reward, done, info = env.step(env.action_space.sample())
    env.render()
env.close()
# Out:
# c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# c:\Python venv\deep-RL-pytorch\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ahmed\Documents\Projects\Deep Reinforcement Learning\Mario\mario.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000005?line=3'>4</a>         env.reset()
#       <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000005?line=4'>5</a>     state, reward, done, info = env.step(env.action_space.sample())
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000005?line=5'>6</a>     env.render()
#       <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000005?line=6'>7</a> env.close()
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\gym\core.py:254, in Wrapper.render(self, mode, **kwargs)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=252'>253</a> def render(self, mode="human", **kwargs):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=253'>254</a>     return self.env.render(mode, **kwargs)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\gym\core.py:254, in Wrapper.render(self, mode, **kwargs)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=252'>253</a> def render(self, mode="human", **kwargs):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=253'>254</a>     return self.env.render(mode, **kwargs)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\nes_py\nes_env.py:379, in NESEnv.render(self, mode)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=372'>373</a>         self.viewer = ImageViewer(
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=373'>374</a>             caption=caption,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=374'>375</a>             height=SCREEN_HEIGHT,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=375'>376</a>             width=SCREEN_WIDTH,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=376'>377</a>         )
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=377'>378</a>     # show the screen on the image viewer
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=378'>379</a>     self.viewer.show(self.screen)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=379'>380</a> elif mode == 'rgb_array':
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=380'>381</a>     return self.screen
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\nes_py\_image_viewer.py:148, in ImageViewer.show(self, frame)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=139'>140</a> image = self.pyglet.image.ImageData(
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=140'>141</a>     frame.shape[1],
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=141'>142</a>     frame.shape[0],
#    (...)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=144'>145</a>     pitch=frame.shape[1]*-3
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=145'>146</a> )
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=146'>147</a> # send the image to the window
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=147'>148</a> image.blit(0, 0, width=self._window.width, height=self._window.height)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=148'>149</a> self._window.flip()
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\__init__.py:903, in ImageData.blit(self, x, y, z, width, height)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=901'>902</a> def blit(self, x, y, z=0, width=None, height=None):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=902'>903</a>     self.get_texture().blit(x, y, z, width, height)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\__init__.py:834, in ImageData.get_texture(self, rectangle, force_rectangle)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=830'>831</a> def get_texture(self, rectangle=False, force_rectangle=False):
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=831'>832</a>     if (not self._current_texture or
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=832'>833</a>             (not self._current_texture._is_rectangle and force_rectangle)):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=833'>834</a>         self._current_texture = self.create_texture(Texture, rectangle, force_rectangle)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=834'>835</a>     return self._current_texture
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\__init__.py:820, in ImageData.create_texture(self, cls, rectangle, force_rectangle)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=796'>797</a> """Create a texture containing this image.
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=797'>798</a>
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=798'>799</a> If the image's dimensions are not powers of 2, a TextureRegion of
#    (...)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=816'>817</a> :rtype: cls or cls.region_class
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=817'>818</a> """
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=818'>819</a> internalformat = self._get_internalformat(self.format)
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=819'>820</a> texture = cls.create(self.width, self.height, internalformat,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=820'>821</a>                      rectangle, force_rectangle)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=821'>822</a> if self.anchor_x or self.anchor_y:
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=822'>823</a>     texture.anchor_x = self.anchor_x
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\__init__.py:1466, in Texture.create(cls, width, height, internalformat, rectangle, force_rectangle, min_filter, mag_filter)
#    <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1463'>1464</a> glGenTextures(1, byref(id))
#    <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1464'>1465</a> glBindTexture(target, id.value)
# -> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1465'>1466</a> glTexParameteri(target, GL_TEXTURE_MIN_FILTER, min_filter)
#    <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1466'>1467</a> glTexParameteri(target, GL_TEXTURE_MAG_FILTER, mag_filter)
#    <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1468'>1469</a> blank = (GLubyte * (texture_width * texture_height * 4))()
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\gl\lib.py:87, in errcheck(result, func, arguments)
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=82'>83</a> class GLException(Exception):
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=83'>84</a>     pass
# ---> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=86'>87</a> def errcheck(result, func, arguments):
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=87'>88</a>     if _debug_gl_trace:
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=88'>89</a>         try:
#
# KeyboardInterrupt:

# %% [markdown]
# # Preprocess Environment

# %%
# 1. Create the base environment
env = gym_super_mario_bros.make('SuperMarioBros-v0')
# 2. Simplify the controls 
env = JoypadSpace(env, SIMPLE_MOVEMENT)
# 3. Grayscale
env = GrayScaleObservation(env, keep_dim=True)
# 4. Wrap inside the Dummy Environment
env = DummyVecEnv([lambda: env])
# 5. Stack the frames
env = VecFrameStack(env, 4, channels_order='last')

# %% [markdown]
# # Train the model

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
callback = TrainAndLoggingCallback(check_freq=50000, save_path=CHECKPOINT_DIR)

# %%
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.000001, n_steps=512)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=1000000, callback=callback)
model.save('LastModel')
# Out:
# Logging to ./logs/PPO_1
# c:\Python venv\deep-RL-pytorch\lib\site-packages\gym_super_mario_bros\smb_env.py:148: RuntimeWarning: overflow encountered in ubyte_scalars
#   return (self.ram[0x86] - self.ram[0x071c]) % 256
# ----------------------------
# | time/              |     |
# |    fps             | 41  |
# |    iterations      | 1   |
# |    time_elapsed    | 12  |
# |    total_timesteps | 512 |
# ----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7             |
# |    iterations           | 2             |
# |    time_elapsed         | 128           |
# |    total_timesteps      | 1024          |
# | train/                  |               |
# |    approx_kl            | 1.3309647e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00203      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 115           |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -2.52e-06     |
# |    value_loss           | 311           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 3            |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 4.385074e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00312      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 37           |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000478    |
# |    value_loss           | 76.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5            |
# |    iterations           | 4            |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 7.666636e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0831       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.192        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000621    |
# |    value_loss           | 1.4          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5            |
# |    iterations           | 5            |
# |    time_elapsed         | 452          |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 9.988784e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0183       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.13         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -3.65e-05    |
# |    value_loss           | 0.993        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5             |
# |    iterations           | 6             |
# |    time_elapsed         | 555           |
# |    total_timesteps      | 3072          |
# | train/                  |               |
# |    approx_kl            | 1.2960518e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.063        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.161         |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.000214     |
# |    value_loss           | 0.855         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5             |
# |    iterations           | 7             |
# |    time_elapsed         | 661           |
# |    total_timesteps      | 3584          |
# | train/                  |               |
# |    approx_kl            | 1.5776954e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00535      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.108         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000328     |
# |    value_loss           | 0.502         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5             |
# |    iterations           | 8             |
# |    time_elapsed         | 770           |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 1.4343881e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0112       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.145         |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -0.000365     |
# |    value_loss           | 0.372         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5            |
# |    iterations           | 9            |
# |    time_elapsed         | 880          |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 6.420887e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.00569      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.104        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000146    |
# |    value_loss           | 0.304        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5            |
# |    iterations           | 10           |
# |    time_elapsed         | 991          |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 1.596869e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | -0.00474     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0844       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 3.83e-07     |
# |    value_loss           | 0.286        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5             |
# |    iterations           | 11            |
# |    time_elapsed         | 1100          |
# |    total_timesteps      | 5632          |
# | train/                  |               |
# |    approx_kl            | 2.3923349e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00528      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0972        |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -3.92e-05     |
# |    value_loss           | 0.319         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5             |
# |    iterations           | 12            |
# |    time_elapsed         | 1210          |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | 1.0878546e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00433       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.121         |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000223     |
# |    value_loss           | 0.336         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5             |
# |    iterations           | 13            |
# |    time_elapsed         | 1319          |
# |    total_timesteps      | 6656          |
# | train/                  |               |
# |    approx_kl            | 1.9341824e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.00555      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.269         |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000535     |
# |    value_loss           | 0.365         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 14            |
# |    time_elapsed         | 1434          |
# |    total_timesteps      | 7168          |
# | train/                  |               |
# |    approx_kl            | 1.4785794e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0083       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0796        |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000287     |
# |    value_loss           | 0.198         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 15            |
# |    time_elapsed         | 1553          |
# |    total_timesteps      | 7680          |
# | train/                  |               |
# |    approx_kl            | 1.2035249e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00282       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0824        |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000197     |
# |    value_loss           | 0.207         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 16            |
# |    time_elapsed         | 1663          |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.2342236e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | -0.0049       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.079         |
# |    n_updates            | 150           |
# |    policy_gradient_loss | -0.000253     |
# |    value_loss           | 0.189         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 17           |
# |    time_elapsed         | 1773         |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 3.382936e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.0119       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 122          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.000139     |
# |    value_loss           | 365          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 18            |
# |    time_elapsed         | 1882          |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 2.1758839e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.95         |
# |    explained_variance   | 0.00909       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 63.4          |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00023      |
# |    value_loss           | 106           |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 19            |
# |    time_elapsed         | 1991          |
# |    total_timesteps      | 9728          |
# | train/                  |               |
# |    approx_kl            | 3.2662065e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0754        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.141         |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000269     |
# |    value_loss           | 1.09          |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 20            |
# |    time_elapsed         | 2101          |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 2.2190507e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0834        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.164         |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000192     |
# |    value_loss           | 0.866         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 21            |
# |    time_elapsed         | 2210          |
# |    total_timesteps      | 10752         |
# | train/                  |               |
# |    approx_kl            | 1.1399621e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0136       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.191         |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000194     |
# |    value_loss           | 0.764         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 22            |
# |    time_elapsed         | 2319          |
# |    total_timesteps      | 11264         |
# | train/                  |               |
# |    approx_kl            | 1.4361576e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0189       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.145         |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000157     |
# |    value_loss           | 0.468         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 23            |
# |    time_elapsed         | 2428          |
# |    total_timesteps      | 11776         |
# | train/                  |               |
# |    approx_kl            | 1.4277524e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00209       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.168         |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.000214     |
# |    value_loss           | 0.563         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 24           |
# |    time_elapsed         | 2537         |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 1.744018e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.012       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.237        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000251    |
# |    value_loss           | 0.416        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 25           |
# |    time_elapsed         | 2645         |
# |    total_timesteps      | 12800        |
# | train/                  |              |
# |    approx_kl            | 1.320662e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00375      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0745       |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.000169    |
# |    value_loss           | 0.367        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 26            |
# |    time_elapsed         | 2756          |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 1.5062164e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00466      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.208         |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000299     |
# |    value_loss           | 0.396         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 27           |
# |    time_elapsed         | 2865         |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 4.071393e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.00262      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.128        |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -4.93e-05    |
# |    value_loss           | 0.278        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 28            |
# |    time_elapsed         | 2983          |
# |    total_timesteps      | 14336         |
# | train/                  |               |
# |    approx_kl            | 2.4929992e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00479      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.129         |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.000415     |
# |    value_loss           | 0.238         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 29           |
# |    time_elapsed         | 3099         |
# |    total_timesteps      | 14848        |
# | train/                  |              |
# |    approx_kl            | 7.482944e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00473     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.134        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -8.23e-05    |
# |    value_loss           | 0.213        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 30            |
# |    time_elapsed         | 3212          |
# |    total_timesteps      | 15360         |
# | train/                  |               |
# |    approx_kl            | 1.1792406e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00558      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.057         |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000219     |
# |    value_loss           | 0.142         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 31            |
# |    time_elapsed         | 3330          |
# |    total_timesteps      | 15872         |
# | train/                  |               |
# |    approx_kl            | 1.7285813e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00368      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0959        |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000244     |
# |    value_loss           | 0.201         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 32            |
# |    time_elapsed         | 3444          |
# |    total_timesteps      | 16384         |
# | train/                  |               |
# |    approx_kl            | 2.4209847e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00112      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.125         |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000444     |
# |    value_loss           | 0.276         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 33            |
# |    time_elapsed         | 3562          |
# |    total_timesteps      | 16896         |
# | train/                  |               |
# |    approx_kl            | 2.6194495e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.0223        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 164           |
# |    n_updates            | 320           |
# |    policy_gradient_loss | 1.9e-05       |
# |    value_loss           | 372           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 34           |
# |    time_elapsed         | 3670         |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 9.122072e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0578       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 35.8         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00013     |
# |    value_loss           | 61           |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 35            |
# |    time_elapsed         | 3784          |
# |    total_timesteps      | 17920         |
# | train/                  |               |
# |    approx_kl            | 2.2477703e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.14          |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0888        |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -0.000124     |
# |    value_loss           | 0.603         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 36            |
# |    time_elapsed         | 3896          |
# |    total_timesteps      | 18432         |
# | train/                  |               |
# |    approx_kl            | 6.8964437e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.217         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.167         |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -4.09e-05     |
# |    value_loss           | 0.516         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 37            |
# |    time_elapsed         | 4002          |
# |    total_timesteps      | 18944         |
# | train/                  |               |
# |    approx_kl            | 1.3177516e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.044         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0815        |
# |    n_updates            | 360           |
# |    policy_gradient_loss | -8.22e-05     |
# |    value_loss           | 0.342         |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 4              |
# |    iterations           | 38             |
# |    time_elapsed         | 4114           |
# |    total_timesteps      | 19456          |
# | train/                  |                |
# |    approx_kl            | 1.22714555e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.94          |
# |    explained_variance   | 0.0938         |
# |    learning_rate        | 1e-06          |
# |    loss                 | 0.0603         |
# |    n_updates            | 370            |
# |    policy_gradient_loss | -0.00016       |
# |    value_loss           | 0.34           |
# --------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 39          |
# |    time_elapsed         | 4226        |
# |    total_timesteps      | 19968       |
# | train/                  |             |
# |    approx_kl            | 5.44684e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | -0.0055     |
# |    learning_rate        | 1e-06       |
# |    loss                 | 0.0721      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -4.47e-05   |
# |    value_loss           | 0.227       |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 40            |
# |    time_elapsed         | 4340          |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 5.7623256e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00694      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.114         |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -3.99e-05     |
# |    value_loss           | 0.262         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 41            |
# |    time_elapsed         | 4448          |
# |    total_timesteps      | 20992         |
# | train/                  |               |
# |    approx_kl            | 6.0813036e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00248      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.086         |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -6.68e-05     |
# |    value_loss           | 0.188         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 42           |
# |    time_elapsed         | 4565         |
# |    total_timesteps      | 21504        |
# | train/                  |              |
# |    approx_kl            | 9.628129e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.000803     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.096        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000107    |
# |    value_loss           | 0.227        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 43            |
# |    time_elapsed         | 4680          |
# |    total_timesteps      | 22016         |
# | train/                  |               |
# |    approx_kl            | 3.8606697e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0065       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0842        |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -0.000467     |
# |    value_loss           | 0.178         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 44            |
# |    time_elapsed         | 4789          |
# |    total_timesteps      | 22528         |
# | train/                  |               |
# |    approx_kl            | 1.7060782e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.00917       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0806        |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.000201     |
# |    value_loss           | 0.18          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 45           |
# |    time_elapsed         | 4899         |
# |    total_timesteps      | 23040        |
# | train/                  |              |
# |    approx_kl            | 5.532638e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.00903     |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0602       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000663    |
# |    value_loss           | 0.128        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 46            |
# |    time_elapsed         | 5011          |
# |    total_timesteps      | 23552         |
# | train/                  |               |
# |    approx_kl            | 2.3989822e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00966      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0765        |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000258     |
# |    value_loss           | 0.157         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 47            |
# |    time_elapsed         | 5123          |
# |    total_timesteps      | 24064         |
# | train/                  |               |
# |    approx_kl            | 5.8712903e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0056       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0882        |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -0.000721     |
# |    value_loss           | 0.179         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 48           |
# |    time_elapsed         | 5234         |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 7.960829e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0021       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 4.56         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -8.92e-05    |
# |    value_loss           | 10.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4           |
# |    iterations           | 49          |
# |    time_elapsed         | 5344        |
# |    total_timesteps      | 25088       |
# | train/                  |             |
# |    approx_kl            | 5.23919e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.94       |
# |    explained_variance   | 0.0578      |
# |    learning_rate        | 1e-06       |
# |    loss                 | 151         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.000301    |
# |    value_loss           | 384         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 50            |
# |    time_elapsed         | 5453          |
# |    total_timesteps      | 25600         |
# | train/                  |               |
# |    approx_kl            | 1.4984398e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00329      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0725        |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000103     |
# |    value_loss           | 0.536         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 51           |
# |    time_elapsed         | 5562         |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 1.638534e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.22         |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.255        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000138    |
# |    value_loss           | 0.402        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 52            |
# |    time_elapsed         | 5669          |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 3.1391624e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | 0.011         |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0652        |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000365     |
# |    value_loss           | 0.214         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 53            |
# |    time_elapsed         | 5782          |
# |    total_timesteps      | 27136         |
# | train/                  |               |
# |    approx_kl            | 3.9197388e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.00143      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.147         |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -0.000365     |
# |    value_loss           | 0.256         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 54           |
# |    time_elapsed         | 5894         |
# |    total_timesteps      | 27648        |
# | train/                  |              |
# |    approx_kl            | 1.080404e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.0878       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0904       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00011     |
# |    value_loss           | 0.199        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 55            |
# |    time_elapsed         | 6004          |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 2.8235605e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.94         |
# |    explained_variance   | -0.0145       |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0586        |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -0.000346     |
# |    value_loss           | 0.174         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 56           |
# |    time_elapsed         | 6115         |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 1.119799e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.116        |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -9.88e-05    |
# |    value_loss           | 0.187        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 57            |
# |    time_elapsed         | 6224          |
# |    total_timesteps      | 29184         |
# | train/                  |               |
# |    approx_kl            | 2.2313325e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | 0.0366        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0642        |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.000261     |
# |    value_loss           | 0.174         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 58           |
# |    time_elapsed         | 6335         |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 2.741057e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.94        |
# |    explained_variance   | -0.0094      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0645       |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.000288    |
# |    value_loss           | 0.182        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 59            |
# |    time_elapsed         | 6448          |
# |    total_timesteps      | 30208         |
# | train/                  |               |
# |    approx_kl            | 4.4227345e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00202      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.121         |
# |    n_updates            | 580           |
# |    policy_gradient_loss | -0.000409     |
# |    value_loss           | 0.178         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 60            |
# |    time_elapsed         | 6558          |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 3.2515964e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.93         |
# |    explained_variance   | -0.00511      |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.0634        |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -0.0004       |
# |    value_loss           | 0.118         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 61           |
# |    time_elapsed         | 6669         |
# |    total_timesteps      | 31232        |
# | train/                  |              |
# |    approx_kl            | 3.917818e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.00201      |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0843       |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.000383    |
# |    value_loss           | 0.187        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 62           |
# |    time_elapsed         | 6777         |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 4.025281e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# ...
# |    iterations           | 587           |
# |    time_elapsed         | 65330         |
# |    total_timesteps      | 300544        |
# | train/                  |               |
# |    approx_kl            | 0.00084946875 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.48         |
# |    explained_variance   | -0.365        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.232         |
# |    n_updates            | 5860          |
# |    policy_gradient_loss | -0.00187      |
# |    value_loss           | 1.3           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 588          |
# |    time_elapsed         | 65441        |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0007027774 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | -0.562       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.318        |
# |    n_updates            | 5870         |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 1.1          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 589           |
# |    time_elapsed         | 65552         |
# |    total_timesteps      | 301568        |
# | train/                  |               |
# |    approx_kl            | 0.00032118056 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | -0.332        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.127         |
# |    n_updates            | 5880          |
# |    policy_gradient_loss | -0.00127      |
# |    value_loss           | 0.722         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 590          |
# |    time_elapsed         | 65663        |
# |    total_timesteps      | 302080       |
# | train/                  |              |
# |    approx_kl            | 8.008676e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0.547        |
# |    learning_rate        | 1e-06        |
# |    loss                 | 76.3         |
# |    n_updates            | 5890         |
# |    policy_gradient_loss | -0.000205    |
# |    value_loss           | 162          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 591           |
# |    time_elapsed         | 65774         |
# |    total_timesteps      | 302592        |
# | train/                  |               |
# |    approx_kl            | 0.00057424814 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.48         |
# |    explained_variance   | -0.333        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.177         |
# |    n_updates            | 5900          |
# |    policy_gradient_loss | -0.0011       |
# |    value_loss           | 0.421         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 592           |
# |    time_elapsed         | 65884         |
# |    total_timesteps      | 303104        |
# | train/                  |               |
# |    approx_kl            | 0.00045352522 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.48         |
# |    explained_variance   | -0.167        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.204         |
# |    n_updates            | 5910          |
# |    policy_gradient_loss | -0.000665     |
# |    value_loss           | 0.339         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 593          |
# |    time_elapsed         | 65995        |
# |    total_timesteps      | 303616       |
# | train/                  |              |
# |    approx_kl            | 0.0013343765 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | -0.255       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.103        |
# |    n_updates            | 5920         |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 0.263        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 594           |
# |    time_elapsed         | 66106         |
# |    total_timesteps      | 304128        |
# | train/                  |               |
# |    approx_kl            | 0.00023565453 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.49         |
# |    explained_variance   | -0.749        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.114         |
# |    n_updates            | 5930          |
# |    policy_gradient_loss | -0.000406     |
# |    value_loss           | 0.222         |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4             |
# |    iterations           | 595           |
# |    time_elapsed         | 66216         |
# |    total_timesteps      | 304640        |
# | train/                  |               |
# |    approx_kl            | 0.00010848534 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.49         |
# |    explained_variance   | -0.887        |
# |    learning_rate        | 1e-06         |
# |    loss                 | 0.106         |
# |    n_updates            | 5940          |
# |    policy_gradient_loss | -0.000343     |
# |    value_loss           | 0.225         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 596          |
# |    time_elapsed         | 66326        |
# |    total_timesteps      | 305152       |
# | train/                  |              |
# |    approx_kl            | 0.0006219329 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | -0.546       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0881       |
# |    n_updates            | 5950         |
# |    policy_gradient_loss | -0.000801    |
# |    value_loss           | 0.189        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4            |
# |    iterations           | 597          |
# |    time_elapsed         | 66435        |
# |    total_timesteps      | 305664       |
# | train/                  |              |
# |    approx_kl            | 0.0006971465 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | -0.934       |
# |    learning_rate        | 1e-06        |
# |    loss                 | 0.0981       |
# |    n_updates            | 5960         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 0.189        |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ahmed\Documents\Projects\Deep Reinforcement Learning\Mario\mario.ipynb Cell 13' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000017?line=0'>1</a> model.learn(total_timesteps=1000000, callback=callback)
#       <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000017?line=1'>2</a> model.save('LastModel')
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\stable_baselines3\ppo\ppo.py:299, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=285'>286</a> def learn(
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=286'>287</a>     self,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=287'>288</a>     total_timesteps: int,
#    (...)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=295'>296</a>     reset_num_timesteps: bool = True,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=296'>297</a> ) -> "PPO":
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=298'>299</a>     return super(PPO, self).learn(
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=299'>300</a>         total_timesteps=total_timesteps,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=300'>301</a>         callback=callback,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=301'>302</a>         log_interval=log_interval,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=302'>303</a>         eval_env=eval_env,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=303'>304</a>         eval_freq=eval_freq,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=304'>305</a>         n_eval_episodes=n_eval_episodes,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=305'>306</a>         tb_log_name=tb_log_name,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=306'>307</a>         eval_log_path=eval_log_path,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=307'>308</a>         reset_num_timesteps=reset_num_timesteps,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=308'>309</a>     )
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:270, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/on_policy_algorithm.py?line=266'>267</a>         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/on_policy_algorithm.py?line=267'>268</a>         self.logger.dump(step=self.num_timesteps)
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/on_policy_algorithm.py?line=269'>270</a>     self.train()
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/on_policy_algorithm.py?line=271'>272</a> callback.on_training_end()
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/on_policy_algorithm.py?line=273'>274</a> return self
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\stable_baselines3\ppo\ppo.py:259, in PPO.train(self)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=256'>257</a> # Optimization step
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=257'>258</a> self.policy.optimizer.zero_grad()
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=258'>259</a> loss.backward()
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=259'>260</a> # Clip grad norm
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/ppo/ppo.py?line=260'>261</a> th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\torch\_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/_tensor.py?line=297'>298</a> if has_torch_function_unary(self):
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/_tensor.py?line=298'>299</a>     return handle_torch_function(
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/_tensor.py?line=299'>300</a>         Tensor.backward,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/_tensor.py?line=300'>301</a>         (self,),
#    (...)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/_tensor.py?line=304'>305</a>         create_graph=create_graph,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/_tensor.py?line=305'>306</a>         inputs=inputs)
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/_tensor.py?line=306'>307</a> torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\torch\autograd\__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/autograd/__init__.py?line=150'>151</a> if retain_graph is None:
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/autograd/__init__.py?line=151'>152</a>     retain_graph = create_graph
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/autograd/__init__.py?line=153'>154</a> Variable._execution_engine.run_backward(
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/autograd/__init__.py?line=154'>155</a>     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/torch/autograd/__init__.py?line=155'>156</a>     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %% [markdown]
# # Test the model

# %%
model = PPO.load('./train/best_model_300000')
state = env.reset()
while True: 
    action, _ = model.predict(state)
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\ahmed\Documents\Projects\Deep Reinforcement Learning\Mario\mario.ipynb Cell 15' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000016?line=3'>4</a> action, _ = model.predict(state)
#       <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000016?line=4'>5</a> state, reward, done, info = env.step(action)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ahmed/Documents/Projects/Deep%20Reinforcement%20Learning/Mario/mario.ipynb#ch0000016?line=5'>6</a> env.render()
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:281, in VecEnvWrapper.render(self, mode)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=279'>280</a> def render(self, mode: str = "human") -> Optional[np.ndarray]:
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=280'>281</a>     return self.venv.render(mode=mode)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:85, in DummyVecEnv.render(self, mode)
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=72'>73</a> """
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=73'>74</a> Gym environment rendering. If there are multiple environments then
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=74'>75</a> they are tiled together in one image via ``BaseVecEnv.render()``.
#    (...)
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=81'>82</a> :param mode: The rendering type.
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=82'>83</a> """
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=83'>84</a> if self.num_envs == 1:
# ---> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=84'>85</a>     return self.envs[0].render(mode=mode)
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=85'>86</a> else:
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=86'>87</a>     return super().render(mode=mode)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\gym\core.py:254, in Wrapper.render(self, mode, **kwargs)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=252'>253</a> def render(self, mode="human", **kwargs):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=253'>254</a>     return self.env.render(mode, **kwargs)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\gym\core.py:254, in Wrapper.render(self, mode, **kwargs)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=252'>253</a> def render(self, mode="human", **kwargs):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=253'>254</a>     return self.env.render(mode, **kwargs)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\gym\core.py:254, in Wrapper.render(self, mode, **kwargs)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=252'>253</a> def render(self, mode="human", **kwargs):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/gym/core.py?line=253'>254</a>     return self.env.render(mode, **kwargs)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\nes_py\nes_env.py:379, in NESEnv.render(self, mode)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=372'>373</a>         self.viewer = ImageViewer(
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=373'>374</a>             caption=caption,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=374'>375</a>             height=SCREEN_HEIGHT,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=375'>376</a>             width=SCREEN_WIDTH,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=376'>377</a>         )
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=377'>378</a>     # show the screen on the image viewer
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=378'>379</a>     self.viewer.show(self.screen)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=379'>380</a> elif mode == 'rgb_array':
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/nes_env.py?line=380'>381</a>     return self.screen
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\nes_py\_image_viewer.py:148, in ImageViewer.show(self, frame)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=139'>140</a> image = self.pyglet.image.ImageData(
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=140'>141</a>     frame.shape[1],
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=141'>142</a>     frame.shape[0],
#    (...)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=144'>145</a>     pitch=frame.shape[1]*-3
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=145'>146</a> )
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=146'>147</a> # send the image to the window
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=147'>148</a> image.blit(0, 0, width=self._window.width, height=self._window.height)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/nes_py/_image_viewer.py?line=148'>149</a> self._window.flip()
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\__init__.py:903, in ImageData.blit(self, x, y, z, width, height)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=901'>902</a> def blit(self, x, y, z=0, width=None, height=None):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=902'>903</a>     self.get_texture().blit(x, y, z, width, height)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\__init__.py:834, in ImageData.get_texture(self, rectangle, force_rectangle)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=830'>831</a> def get_texture(self, rectangle=False, force_rectangle=False):
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=831'>832</a>     if (not self._current_texture or
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=832'>833</a>             (not self._current_texture._is_rectangle and force_rectangle)):
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=833'>834</a>         self._current_texture = self.create_texture(Texture, rectangle, force_rectangle)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=834'>835</a>     return self._current_texture
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\__init__.py:820, in ImageData.create_texture(self, cls, rectangle, force_rectangle)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=796'>797</a> """Create a texture containing this image.
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=797'>798</a>
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=798'>799</a> If the image's dimensions are not powers of 2, a TextureRegion of
#    (...)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=816'>817</a> :rtype: cls or cls.region_class
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=817'>818</a> """
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=818'>819</a> internalformat = self._get_internalformat(self.format)
# --> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=819'>820</a> texture = cls.create(self.width, self.height, internalformat,
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=820'>821</a>                      rectangle, force_rectangle)
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=821'>822</a> if self.anchor_x or self.anchor_y:
#     <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=822'>823</a>     texture.anchor_x = self.anchor_x
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\image\__init__.py:1465, in Texture.create(cls, width, height, internalformat, rectangle, force_rectangle, min_filter, mag_filter)
#    <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1462'>1463</a> id = GLuint()
#    <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1463'>1464</a> glGenTextures(1, byref(id))
# -> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1464'>1465</a> glBindTexture(target, id.value)
#    <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1465'>1466</a> glTexParameteri(target, GL_TEXTURE_MIN_FILTER, min_filter)
#    <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/image/__init__.py?line=1466'>1467</a> glTexParameteri(target, GL_TEXTURE_MAG_FILTER, mag_filter)
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\pyglet\gl\lib.py:87, in errcheck(result, func, arguments)
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=82'>83</a> class GLException(Exception):
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=83'>84</a>     pass
# ---> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=86'>87</a> def errcheck(result, func, arguments):
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=87'>88</a>     if _debug_gl_trace:
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/pyglet/gl/lib.py?line=88'>89</a>         try:
#
# File _pydevd_bundle/pydevd_cython.pyx:1363, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:1664, in _pydevd_bundle.pydevd_cython.ThreadTracer.__call__()
#
# File c:\Python venv\deep-RL-pytorch\lib\site-packages\debugpy\_vendored\pydevd\_pydev_bundle\pydev_is_thread_alive.py:9, in is_thread_alive(t)
#       <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_is_thread_alive.py?line=5'>6</a> _temp = threading.Thread()
#       <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_is_thread_alive.py?line=6'>7</a> if hasattr(_temp, '_is_stopped'):  # Python 3.x has this
# ----> <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_is_thread_alive.py?line=8'>9</a>     def is_thread_alive(t):
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_is_thread_alive.py?line=9'>10</a>         return not t._is_stopped
#      <a href='file:///c%3A/Python%20venv/deep-RL-pytorch/lib/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_is_thread_alive.py?line=11'>12</a> elif hasattr(_temp, '_Thread__stopped'):  # Python 2.x has this
#
# KeyboardInterrupt:

# %%
env.close()
