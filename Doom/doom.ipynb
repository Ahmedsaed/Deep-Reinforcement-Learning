# %% [markdown]
# # Imports & Init

# %%
from vizdoom import *
import numpy as np
import random
import time
from gym import Env
from gym.spaces import Box, Discrete
import cv2
import os
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_checker import check_env
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# %%
game = DoomGame()
game.load_config('Github repos\\ViZDoom\\scenarios\\basic.cfg')
game.init()

# %%
actions = np.identity(3, dtype=np.uint8)

# %% [markdown]
# # Init Test

# %%
# Loop through episodes 
episodes = 10 
for episode in range(episodes): 
    # Create a new episode or game 
    game.new_episode()
    # Check the game isn't done 
    while not game.is_episode_finished(): 
        # Get the game state 
        state = game.get_state()
        # Get the game image 
        img = state.screen_buffer
        # Get the game variables - ammo
        info = state.game_variables
        # Take an action
        reward = game.make_action(random.choice(actions),4)
        # Print rewward 
        print('reward:', reward) 
        time.sleep(0.02)
    print('Result:', game.get_total_reward())
    time.sleep(2)

# %%
game.close()

# %% [markdown]
# # Setup VizDoom OpenAI Gym Environment

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env): 
    # Function that is called when we start the env
    def __init__(self, render=False): 
        # Inherit from Env
        super().__init__()
        # Setup the game 
        self.game = DoomGame()
        self.game.load_config('Github repos\\ViZDoom\\scenarios\\basic.cfg')
        
        # Render frame logic
        self.game.set_window_visible(render)
        
        # Start the game 
        self.game.init()
        
        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100,160,1), dtype=np.uint8) 
        self.action_space = Discrete(3)
        
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step 
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) 
        
        # Get all the other stuff we need to retun 
        if self.game.get_state(): 
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
            info = ammo
        else: 
            state = np.zeros(self.observation_space.shape)
            info = 0 
        
        info = {"info":info}
        done = self.game.is_episode_finished()
        
        return state, reward, done, info 
    
    # Define how to render the game or environment 
    def render(): 
        pass
    
    # What happens when we start a new game 
    def reset(self): 
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)
    
    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state
    
    # Call to close down the game
    def close(self): 
        self.game.close()

# %%
env = VizDoomGym(render=True)
check_env(env)

# %%
env.close()

# %% [markdown]
# # Setup Callback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_basic'
LOG_DIR = './logs/log_basic'

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# # Train a PPO Model

# %%
env = VizDoomGym()

# %%
model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=2048)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_basic\PPO_7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.4     |
# |    ep_rew_mean     | -57.3    |
# | time/              |          |
# |    fps             | 20       |
# |    iterations      | 1        |
# |    time_elapsed    | 100      |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.6         |
# |    ep_rew_mean          | -54.5        |
# | time/                   |              |
# |    fps                  | 15           |
# |    iterations           | 2            |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0036911701 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 5.42e-05     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.38e+03     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | 0.000626     |
# |    value_loss           | 2.85e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.3        |
# |    ep_rew_mean          | -73.3       |
# | time/                   |             |
# |    fps                  | 14          |
# |    iterations           | 3           |
# |    time_elapsed         | 426         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015340865 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.113       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.34e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 2.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | -45         |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 4           |
# |    time_elapsed         | 585         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015647447 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.31e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -2.06e-05   |
# |    value_loss           | 2.95e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | -38.8       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 5           |
# |    time_elapsed         | 745         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012088646 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.4e+03     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.00092     |
# |    value_loss           | 4.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.3        |
# |    ep_rew_mean          | -24.7       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 6           |
# |    time_elapsed         | 905         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008689825 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.992      |
# |    explained_variance   | 0.421       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.19e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | 0.000619    |
# |    value_loss           | 4.58e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.6        |
# |    ep_rew_mean          | -27.5       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 7           |
# |    time_elapsed         | 1062        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014010867 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.19e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 3.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.1        |
# |    ep_rew_mean          | -18.1       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 8           |
# |    time_elapsed         | 1224        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012639293 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.806      |
# |    explained_variance   | 0.557       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000753   |
# |    value_loss           | 2.92e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | -50.9       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 9           |
# |    time_elapsed         | 1385        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026804652 |
# |    clip_fraction        | 0.26        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0163      |
# |    value_loss           | 2.6e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.3        |
# |    ep_rew_mean          | -28.1       |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 10          |
# |    time_elapsed         | 1541        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.025513325 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.51e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 3.68e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.7       |
# |    ep_rew_mean          | 17.7       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 11         |
# |    time_elapsed         | 1700       |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.05625162 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.64      |
# |    explained_variance   | 0.743      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 894        |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.0067     |
# |    value_loss           | 2.15e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 22.3       |
# |    ep_rew_mean          | -13.3      |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 12         |
# |    time_elapsed         | 1857       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.06468648 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.7       |
# |    explained_variance   | 0.626      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.84e+03   |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 0.0715     |
# |    value_loss           | 2.95e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.3       |
# |    ep_rew_mean          | 15.9       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 13         |
# |    time_elapsed         | 2016       |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.04271773 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.845     |
# |    explained_variance   | 0.589      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.36e+03   |
# |    n_updates            | 120        |
# |    policy_gradient_loss | 0.0162     |
# |    value_loss           | 2.17e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.2        |
# |    ep_rew_mean          | 4.43        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 14          |
# |    time_elapsed         | 2176        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017644178 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.767       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.41e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.00862     |
# |    value_loss           | 1.95e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 18.8       |
# |    ep_rew_mean          | 6.9        |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 15         |
# |    time_elapsed         | 2336       |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01520049 |
# |    clip_fraction        | 0.234      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.679     |
# |    explained_variance   | 0.73       |
# |    learning_rate        | 0.0001     |
# |    loss                 | 860        |
# |    n_updates            | 140        |
# |    policy_gradient_loss | 0.00996    |
# |    value_loss           | 2.28e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.8        |
# |    ep_rew_mean          | 20.5        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 16          |
# |    time_elapsed         | 2496        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013712794 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.709      |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 923         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00387     |
# |    value_loss           | 2.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.7        |
# |    ep_rew_mean          | 19.7        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 17          |
# |    time_elapsed         | 2658        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.031123187 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.26e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0128      |
# |    value_loss           | 2.31e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 12.8       |
# |    ep_rew_mean          | 40.9       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 18         |
# |    time_elapsed         | 2817       |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.02467217 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.701     |
# |    explained_variance   | 0.834      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 662        |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0026    |
# |    value_loss           | 1.78e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.62        |
# |    ep_rew_mean          | 62.5        |
# | time/                   |             |
# |    fps                  | 13          |
# |    iterations           | 19          |
# |    time_elapsed         | 2981        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.038316194 |
# |    clip_fraction        | 0.313       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.47e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00226    |
# |    value_loss           | 2.41e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 7.63       |
# |    ep_rew_mean          | 70.3       |
# | time/                   |            |
# |    fps                  | 13         |
# |    iterations           | 20         |
# |    time_elapsed         | 3149       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03394461 |
# |    clip_fraction        | 0.351      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.732     |
# |    explained_variance   | 0.708      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 585        |
# |    n_updates            | 190        |
# |    policy_gradient_loss | 0.00678    |
# |    value_loss           | 1.56e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.14        |
# |    ep_rew_mean          | 76.1        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 21          |
# |    time_elapsed         | 3316        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.031804703 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.701      |
# |    explained_variance   | 0.551       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 363         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00325    |
# |    value_loss           | 834         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.09        |
# |    ep_rew_mean          | 65.5        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 22          |
# |    time_elapsed         | 3488        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.051842354 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 246         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | 0.0174      |
# |    value_loss           | 541         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.87       |
# |    ep_rew_mean          | 76.3       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 23         |
# |    time_elapsed         | 3663       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.04381048 |
# |    clip_fraction        | 0.25       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.542     |
# |    explained_variance   | 0.855      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 334        |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.00263   |
# |    value_loss           | 721        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.99       |
# |    ep_rew_mean          | 81.3       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 24         |
# |    time_elapsed         | 3836       |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.06989089 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.447     |
# |    explained_variance   | 0.574      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 102        |
# |    n_updates            | 230        |
# |    policy_gradient_loss | 0.0281     |
# |    value_loss           | 277        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 6.6        |
# |    ep_rew_mean          | 72.5       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 25         |
# |    time_elapsed         | 4007       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.06928675 |
# |    clip_fraction        | 0.258      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.401     |
# |    explained_variance   | 0.555      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 36.1       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | 0.0447     |
# |    value_loss           | 149        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.34       |
# |    ep_rew_mean          | 84.8       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 26         |
# |    time_elapsed         | 4201       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.05165271 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.366     |
# |    explained_variance   | 0.794      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 152        |
# |    n_updates            | 250        |
# |    policy_gradient_loss | 0.0106     |
# |    value_loss           | 398        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.73        |
# |    ep_rew_mean          | 82.7        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 27          |
# |    time_elapsed         | 4377        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.080618136 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.379      |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 96.3        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0417      |
# |    value_loss           | 149         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.41        |
# |    ep_rew_mean          | 84.6        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 28          |
# |    time_elapsed         | 4554        |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.037807256 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.406      |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 27.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.044       |
# |    value_loss           | 100         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.95       |
# |    ep_rew_mean          | 82.2       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 29         |
# |    time_elapsed         | 4728       |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.04879545 |
# |    clip_fraction        | 0.173      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.36      |
# |    explained_variance   | 0.378      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 176        |
# |    n_updates            | 280        |
# |    policy_gradient_loss | 0.036      |
# |    value_loss           | 276        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.26        |
# |    ep_rew_mean          | 85.2        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 30          |
# |    time_elapsed         | 4906        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.032360226 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.266      |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 147         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.000586   |
# |    value_loss           | 294         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.75        |
# |    ep_rew_mean          | 87.8        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 31          |
# |    time_elapsed         | 5087        |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014271123 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.249      |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39.4        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.0121      |
# |    value_loss           | 84.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.94        |
# |    ep_rew_mean          | 86.8        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 32          |
# |    time_elapsed         | 5270        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013869053 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.232      |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 48          |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0254      |
# |    value_loss           | 84.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.32        |
# |    ep_rew_mean          | 85          |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 33          |
# |    time_elapsed         | 5448        |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.029360976 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.183      |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.62        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00281     |
# |    value_loss           | 54.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.07        |
# |    ep_rew_mean          | 86.3        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 34          |
# |    time_elapsed         | 5628        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.054765306 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 44.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.0648      |
# |    value_loss           | 82.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.2         |
# |    ep_rew_mean          | 85.8        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 35          |
# |    time_elapsed         | 5810        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.028420962 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.179      |
# |    explained_variance   | 0.508       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 57.8        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.0168      |
# |    value_loss           | 127         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.73        |
# |    ep_rew_mean          | 84          |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 36          |
# |    time_elapsed         | 5990        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.017147932 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.16       |
# |    explained_variance   | 0.763       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 13.3        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0189      |
# |    value_loss           | 41.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.9         |
# |    ep_rew_mean          | 87          |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 37          |
# |    time_elapsed         | 6174        |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.045385152 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.177      |
# |    explained_variance   | 0.651       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 39.5        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.0192      |
# |    value_loss           | 70.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.42        |
# |    ep_rew_mean          | 84.8        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 38          |
# |    time_elapsed         | 6354        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.015886076 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.151      |
# |    explained_variance   | 0.689       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 42          |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.0101      |
# |    value_loss           | 57.5        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.89       |
# |    ep_rew_mean          | 87.2       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 39         |
# |    time_elapsed         | 6533       |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.02521823 |
# |    clip_fraction        | 0.0738     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.139     |
# |    explained_variance   | 0.697      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 6.1        |
# |    n_updates            | 380        |
# |    policy_gradient_loss | 0.0064     |
# |    value_loss           | 51.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.89        |
# |    ep_rew_mean          | 87.3        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 40          |
# |    time_elapsed         | 6717        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.010806084 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.146      |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 8.65        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.0123      |
# |    value_loss           | 56.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.16        |
# |    ep_rew_mean          | 85.7        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 41          |
# |    time_elapsed         | 6902        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.011445312 |
# |    clip_fraction        | 0.0882      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.13       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 9.54        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.014       |
# |    value_loss           | 25.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.98        |
# |    ep_rew_mean          | 87.1        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 42          |
# |    time_elapsed         | 7086        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013987854 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 22.6        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.0197      |
# |    value_loss           | 46.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.84        |
# |    ep_rew_mean          | 87.5        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 43          |
# |    time_elapsed         | 7269        |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008769027 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.1        |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.04        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0123      |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.16       |
# |    ep_rew_mean          | 86.2       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 44         |
# |    time_elapsed         | 7454       |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.01718635 |
# |    clip_fraction        | 0.074      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0916    |
# |    explained_variance   | 0.813      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 7.34       |
# |    n_updates            | 430        |
# |    policy_gradient_loss | 0.0161     |
# |    value_loss           | 26.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.88         |
# |    ep_rew_mean          | 87.4         |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 45           |
# |    time_elapsed         | 7636         |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0076615303 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0934      |
# |    explained_variance   | 0.906        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.71         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.00841      |
# |    value_loss           | 13.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.01        |
# |    ep_rew_mean          | 86.9        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 46          |
# |    time_elapsed         | 7819        |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.024899676 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0872     |
# |    explained_variance   | 0.653       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.02        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0153      |
# |    value_loss           | 58          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.83        |
# |    ep_rew_mean          | 87.7        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 47          |
# |    time_elapsed         | 8000        |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.021034725 |
# |    clip_fraction        | 0.0429      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0909     |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 24.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.0145      |
# |    value_loss           | 22.9        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 3.73       |
# |    ep_rew_mean          | 87.9       |
# | time/                   |            |
# |    fps                  | 12         |
# |    iterations           | 48         |
# |    time_elapsed         | 8179       |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.08415037 |
# |    clip_fraction        | 0.0811     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0815    |
# |    explained_variance   | 0.867      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 11.3       |
# |    n_updates            | 470        |
# |    policy_gradient_loss | -0.0077    |
# |    value_loss           | 15.7       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.16        |
# |    ep_rew_mean          | 86.1        |
# | time/                   |             |
# |    fps                  | 12          |
# |    iterations           | 49          |
# |    time_elapsed         | 8360        |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.051818628 |
# |    clip_fraction        | 0.0517      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0824     |
# |    explained_variance   | 0.667       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.3        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00805     |
# |    value_loss           | 53.4        |
# -----------------------------------------

# %% [markdown]
# # Test the model

# %%
model = PPO.load('train\\train_basic\\best_model_110000.zip')

# %%
env = VizDoomGym(render=True)

# %%
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
mean_reward
# Out:
# c:\Python venv\deep-RL-pytorch\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# 92.6

# %%
env.close()
